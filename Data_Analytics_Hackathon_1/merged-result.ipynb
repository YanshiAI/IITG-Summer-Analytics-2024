# %%
import numpy as np # linear algebra
import pandas as pd

# %%
s1 = pd.read_csv("/kaggle/input/submission1/submission (2).csv")
s2 = pd.read_csv("/kaggle/input/submission2/submission (3).csv")
s3 = pd.read_csv("/kaggle/input/submission3/submission (1).csv")

# %%
s2.head()
# Out:
#    respondent_id  h1n1_vaccine
# 0          26707             0
# 1          26708             0
# 2          26709             1
# 3          26710             1
# 4          26711             0

# %%
s3.head()
# Out:
#    respondent_id  seasonal_vaccine
# 0          26707                 0
# 1          26708                 0
# 2          26709                 1
# 3          26710                 1
# 4          26711                 1

# %%
result = pd.merge(s2,s3,on='respondent_id')

# %%
result.head()
# Out:
#    respondent_id  h1n1_vaccine  seasonal_vaccine
# 0          26707             0                 0
# 1          26708             0                 0
# 2          26709             1                 1
# 3          26710             1                 1
# 4          26711             0                 1

# %%
result.to_csv('result.csv', index=False)

# %%
result.head()
# Out:
#    respondent_id  h1n1_vaccine  seasonal_vaccine
# 0          26707             0                 0
# 1          26708             0                 0
# 2          26709             1                 1
# 3          26710             1                 1
# 4          26711             0                 1
